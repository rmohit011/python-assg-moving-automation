# %%
import os
pc_name=input("enter the name of your pc")
os.chdir(f"C:\\Users\\{pc_name}\\Downloads")
l=os.listdir()
lis=[]
for i in l:
    a=i.split(".")
    try:
        if a[1]=="docx" and "Assignment" in a[0]:
            lis.append(i)
        elif a[1]=="docx" and "Assingment" in a[0]:
            lis.append(i)
    except Exception as e:
        pass
lis1=[]
lis2=[]
for i in lis:
    if "Programming_Assignment" in i:
        lis1.append(i)
        print(i)
    elif "Programming_Assingment" in i:
        lis1.append(i)
    else:
        lis2.append(i)
        print(i)
print(lis1)
print(lis2)
        
string=''
for i in range(1,len(lis1)):
    d=[k for k in lis1[i]]
    
for i in range(28):
    for j in range(1,len(lis1)):
        if lis1[0][i]==lis1[j][i]:
            continue
        else:
            break
    else:
        string=string+lis1[0][i]
print("common string is: ",string)

string1=''
for i in range(1,len(lis1)):
    d=[k for k in lis1[i]]
    
for i in range(15):
    for j in range(1,len(lis2)):
        if lis2[0][i]==lis2[j][i]:
            continue
        else:
            break
    else:
        string1=string1+lis2[0][i]
print("common string is: ",string1)




import shutil
os.mkdir(f"D:\\{string}")
os.mkdir(f"D:\\{string1}")
for i in lis1:
    shutil.move(f"C:\\Users\\{pc_name}\\Downloads\\{i}",f"D:\\{string}\\{i}")
for i in lis2:
    shutil.move(f"C:\\Users\\{pc_name}\\Downloads\\{i}",f"D:\\{string1}\\{i}")
# Out:
# enter the name of your pcaradhana
# Assignment_1 (1).docx
# Assignment_1.docx
# Assignment_2 (1).docx
# Assignment_2.docx
# Assignment_3 (1).docx
# Assignment_3.docx
# Programming_Assignment1(1).docx
# Programming_Assignment1.docx
# Programming_Assignment2(1).docx
# Programming_Assignment2.docx
# Programming_Assignment3(1).docx
# Programming_Assignment3.docx
# ['Programming_Assignment1(1).docx', 'Programming_Assignment1.docx', 'Programming_Assignment2(1).docx', 'Programming_Assignment2.docx', 'Programming_Assignment3(1).docx', 'Programming_Assignment3.docx']
# ['Assignment_1 (1).docx', 'Assignment_1.docx', 'Assignment_2 (1).docx', 'Assignment_2.docx', 'Assignment_3 (1).docx', 'Assignment_3.docx']
# common string is:  Programming_Assignment
# common string is:  Assignment_
